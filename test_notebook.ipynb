# %%
import sys
import random
from datetime import datetime
from collections import namedtuple, Counter
import re
import math
from tabulate import tabulate
import csv
import session13
from session13 import *

# %%
# Traffic violation records NamedTuple
records = namedtuple('records', ['Summons_Number', 'Plate_Id', 'Registration_State', 'Plate_Type','Issue_Date', 'Violation_Code', 'Vehicle_Body_Type', 'Vehicle_Make', 'Violation_Description'])

# %%
tuple_records = fetch_records('nyc_parking_tickets_extract-1.csv')

# %%
# Goal 1
tuple_records
# Out:
# [records(Summons_Number=4006478550, Plate_Id='VAD7274', Registration_State='VA', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 10, 5, 0, 0), Violation_Code=5, Vehicle_Body_Type='4D', Vehicle_Make='BMW', Violation_Description='BUS LANE VIOLATION'),
#  records(Summons_Number=4006462396, Plate_Id='22834JK', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2016, 9, 30, 0, 0), Violation_Code=5, Vehicle_Body_Type='VAN', Vehicle_Make='CHEVR', Violation_Description='BUS LANE VIOLATION'),
#  records(Summons_Number=4007117810, Plate_Id='21791MG', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2017, 4, 10, 0, 0), Violation_Code=5, Vehicle_Body_Type='VAN', Vehicle_Make='DODGE', Violation_Description='BUS LANE VIOLATION'),
# ...

# %%
## Goal 2
show_violations(tuple_records)
# Out:
# Make      Violation
# ------  -----------
# TOYOT           112
# HONDA           106
# FORD            104
# CHEVR            76
# NISSA            70
# DODGE            45
# FRUEH            44
# ME/BE            38
# GMC              35
# HYUND            35
# BMW              34
# LEXUS            26
# INTER            25
# JEEP             22
# NS/OT            18
# SUBAR            18
# INFIN            13
# LINCO            12
# CHRYS            12
# ACURA            12
# AUDI             12
# VOLVO            12
# MITSU            11
# ISUZU            10
# CADIL             9
# KIA               8
# VOLKS             8
# HIN               6
# KENWO             5
#                   5
# ROVER             5
# BUICK             5
# MAZDA             5
# MERCU             4
# JAGUA             3
# SMART             3
# PORSC             3
# WORKH             2
# SATUR             2
# SCION             2
# SAAB              2
# HINO              2
# FIR               1
# ...
